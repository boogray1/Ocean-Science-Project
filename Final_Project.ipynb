# %% [markdown]
# # FINAL

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import csv
import os
from collections import Counter
# %matplotlib inline

# %% [markdown]
# #### Import single CSV

# %%
filename = 'C:\\Users\\Jessica\\Desktop\\Ocean Engineering\\FinalProjectCSVFiles\\deployment0001_RS03INT1-MJ03C-10-TRHPHA301-streamed-trhph_sample_20150420T060513-20150520T210037.csv'
data = np.genfromtxt( filename , delimiter = ',' , skip_header = 1)
print(data1);
# Out:
# [[0.00000000e+00 3.63849871e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]
#  [1.00000000e+00 3.63849873e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]
#  [2.00000000e+00 3.63849875e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]
#  ...
#  [1.21090000e+04 3.64114440e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]
#  [1.21100000e+04 3.64114442e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]
#  [1.21110000e+04 3.64114444e+09 1.00000000e+00 ... 2.00000000e+01
#              nan            nan]]

# %% [markdown]
# #### Graphing Temperature and Resistivity vs. time (hrs)

# %%
t1 = data[:,31] #parcing the time data in hours from start of measurements
T1 = data[:,20] #parcing the Temperature data
R1 = data[:,16] #parcing the Resistivity data


fig1, axarr = plt.subplots(2,figsize=(20,10),sharex=True)
fig1.suptitle('Temperature & Resistivity vs. time')
#plt.xlabel('time')  
#plt.ylabel('Temperature') 
axarr[0].plot(t1,T1)
axarr[1].plot(t1,R1)
#axarr[0].set_title('Axis [1,1]')
axarr[0].set(ylabel='Temp');
axarr[1].set(xlabel='time', ylabel='Resistivity');
